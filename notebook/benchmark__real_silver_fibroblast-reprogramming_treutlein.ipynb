# %%
import cfe
import scanpy as sc
# Out:
# [2025年01月12日 16时35分00秒] INFO
#                                           _____     _ _ ______    _       ______            _
#                                          / ____|   | | |  ____|  | |     |  ____|          | |
#                                         | |     ___| | | |__ __ _| |_ ___| |__  __  ___ __ | | ___  _ __ ___ _ __
#                                         | |    / _ \ | |  __/ _` | __/ _ \  __| \ \/ / '_ \| |/ _ \| '__/ _ \ '__|
#                                         | |___|  __/ | | | | (_| | ||  __/ |____ >  <| |_) | | (_) | | |  __/ |
#                                          \_____\___|_|_|_|  \__,_|\__\___|______/_/\_\ .__/|_|\___/|_|  \___|_|
#                                                                                      | |
#                                                                                      |_|

# %%
fadata = cfe.data.FateAnnData.read_dynverse_simulation_data(data_filename="real/silver/fibroblast-reprogramming_treutlein.rds")
cfe.plot.plot_graph(fadata, color="grouping")

# %%
# TODO: 添加降维
sc.tl.tsne(fadata)
cfe.plot.plot_trajectory(fadata, basis="tsne")
# Out:
# <Axes: title={'center': 'milestone'}, xlabel='tSNE1', ylabel='tSNE2'>
